# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.api.models import Sequential, load_model
from keras.api.layers import Dense
import os
import importlib
import planar_manipulator
importlib.reload(planar_manipulator)
from planar_manipulator import PlanarManipulator

# %%
train_data = pd.read_csv('my_data_noised.csv')
X_data = train_data[['x2', 'y2']].to_numpy()
Y_data = train_data[['q1', 'q2']].to_numpy()


from sklearn.model_selection import train_test_split

X_temp, X_test, Y_temp, Y_test = train_test_split(
    X_data, Y_data, test_size=0.15, random_state=42
)
X_train, X_val, Y_train, Y_val = train_test_split(
    X_temp, Y_temp, test_size=0.176, random_state=42
)

q1_lim = np.array([-np.pi, np.pi])
q2_lim = np.array([-np.pi, np.pi])

robot = PlanarManipulator(1.0, 1.0, q1_lim, q2_lim)

# %%
def mdn_loss(y_true, y_pred):
    n_components = 2
    n_dims = 2

    # Split model outputs and process outputs
    out_pi = y_pred[:, :n_components]
    out_mu = y_pred[:, n_components:n_components + n_components * n_dims]
    out_sigma = y_pred[:, n_components + n_components * n_dims:]

    pi = tf.nn.softmax(out_pi)
    mu = tf.reshape(out_mu, [-1, n_components, n_dims])
    sigma = tf.exp(out_sigma)
    sigma = tf.reshape(sigma, [-1, n_components, n_dims])

    y_true_exp = tf.reshape(y_true, [-1, 1, n_dims])

    # Normalized difference
    norm = (y_true_exp - mu) / sigma

    # Exponent term
    exponent = -0.5 * tf.reduce_sum(tf.square(norm), axis=2)

    # Normalizing coefficient
    coeff = 1.0 / (2.0 * np.pi * tf.reduce_prod(sigma, axis=2))

    # Gaussian component density
    gauss = coeff * tf.exp(exponent)

    
    weighted = pi * gauss
    total_prob = tf.reduce_sum(weighted, axis=1) + 1e-8

    loss = -tf.math.log(total_prob)
    return tf.reduce_mean(loss)

# %%
def mdn_loss_with_joint_penalty(y_true, y_pred):
    n_components = 2
    n_dims = 2

    out_pi = y_pred[:, :n_components]
    out_mu = y_pred[:, n_components:n_components + n_components * n_dims]
    out_sigma = y_pred[:, n_components + n_components * n_dims:]

    pi = tf.nn.softmax(out_pi)
    mu = tf.reshape(out_mu, [-1, n_components, n_dims])
    sigma = tf.exp(out_sigma)
    sigma = tf.reshape(sigma, [-1, n_components, n_dims])

    y_true_exp = tf.reshape(y_true, [-1, 1, n_dims])
    norm = (y_true_exp - mu) / sigma
    exponent = -0.5 * tf.reduce_sum(tf.square(norm), axis=2)
    coeff = 1.0 / (2.0 * np.pi * tf.reduce_prod(sigma, axis=2))
    gauss = coeff * tf.exp(exponent)
    weighted = pi * gauss
    total_prob = tf.reduce_sum(weighted, axis=1) + 1e-8
    mdn_loss = -tf.math.log(total_prob)

    # --- Add joint limit penalty ---
    q1_min, q1_max = -np.pi/2, np.pi/2
    q2_min, q2_max = -np.pi/3, np.pi/3

    q1 = mu[:, :, 0]
    q2 = mu[:, :, 1]

    q1_violation = tf.maximum(0.0, q1 - q1_max) + tf.maximum(0.0, q1_min - q1)
    q2_violation = tf.maximum(0.0, q2 - q2_max) + tf.maximum(0.0, q2_min - q2)

    joint_penalty = tf.reduce_sum(q1_violation + q2_violation, axis=1)

    return tf.reduce_mean(mdn_loss + 10.0 * joint_penalty)  # Adjust weight if needed

# %%
def build_mdn_model():
    model = Sequential([
        Dense(50, activation='relu', input_shape=(2,)),
        Dense(50, activation='relu'),
        Dense(50, activation='relu'),

        Dense(10)
    ])
    return model

# %%
model_path = 'models/my_mdn2_1_model_50_50_50.keras'

if os.path.exists(model_path):
    model = load_model(model_path, custom_objects={'mdn_loss': mdn_loss})
else:
    model = build_mdn_model()
    model.compile(optimizer='adam', loss=mdn_loss)
    model.summary()

    history = model.fit(
        X_train, Y_train,
        epochs=100,
        batch_size=32,
        validation_data=(X_val, Y_val)
    )
    model.save(model_path)
# Out:
# C:\Users\yanto\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           510 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,760 (22.50 KB)
#  Trainable params: 5,760 (22.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6173 - val_loss: 0.1011
# Epoch 2/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -0.0421 - val_loss: -1.1671
# Epoch 3/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -1.3746 - val_loss: -1.8317
# Epoch 4/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -1.7635 - val_loss: -1.7600
# Epoch 5/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -1.9255 - val_loss: -2.1040
# Epoch 6/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -1.9965 - val_loss: -2.0687
# Epoch 7/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0476 - val_loss: -1.6659
# Epoch 8/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0319 - val_loss: -1.9118
# Epoch 9/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: -2.0426 - val_loss: -2.1915
# Epoch 10/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0642 - val_loss: -2.1264
# Epoch 11/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0564 - val_loss: -2.1451
# Epoch 12/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0867 - val_loss: -2.1583
# Epoch 13/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0760 - val_loss: -1.9166
# Epoch 14/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0868 - val_loss: -1.9678
# Epoch 15/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0890 - val_loss: -2.1431
# Epoch 16/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1117 - val_loss: -2.2013
# Epoch 17/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1249 - val_loss: -2.1460
# Epoch 18/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: -2.1073 - val_loss: -2.1680
# Epoch 19/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1089 - val_loss: -2.2099
# Epoch 20/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: -2.1381 - val_loss: -1.6932
# Epoch 21/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.0996 - val_loss: -2.1526
# Epoch 22/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1401 - val_loss: -2.1346
# Epoch 23/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1487 - val_loss: -1.9565
# Epoch 24/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1189 - val_loss: -2.2241
# Epoch 25/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1597 - val_loss: -2.1388
# Epoch 26/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1342 - val_loss: -2.1747
# Epoch 27/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1688 - val_loss: -2.0493
# Epoch 28/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: -2.1617 - val_loss: -1.6976
# Epoch 29/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: -2.1272 - val_loss: -2.0778
# Epoch 30/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1611 - val_loss: -2.1980
# Epoch 31/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: -2.1797 - val_loss: -2.0659
# Epoch 32/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1876 - val_loss: -1.9162
# Epoch 33/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1564 - val_loss: -2.2206
# Epoch 34/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1937 - val_loss: -2.0038
# Epoch 35/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.1766 - val_loss: -1.9064
# Epoch 36/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1779 - val_loss: -2.1246
# Epoch 37/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1988 - val_loss: -2.2083
# Epoch 38/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1750 - val_loss: -2.0815
# Epoch 39/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2015 - val_loss: -2.2149
# Epoch 40/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1779 - val_loss: -2.2058
# Epoch 41/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1962 - val_loss: -2.0849
# Epoch 42/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1772 - val_loss: -2.1673
# Epoch 43/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1965 - val_loss: -2.2442
# Epoch 44/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2092 - val_loss: -2.2032
# Epoch 45/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1823 - val_loss: -2.2429
# Epoch 46/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2137 - val_loss: -2.2235
# Epoch 47/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1662 - val_loss: -2.1900
# Epoch 48/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1714 - val_loss: -2.2241
# Epoch 49/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1915 - val_loss: -2.1341
# Epoch 50/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2000 - val_loss: -2.0844
# Epoch 51/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1854 - val_loss: -2.2378
# Epoch 52/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2335 - val_loss: -2.2326
# Epoch 53/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2087 - val_loss: -1.9736
# Epoch 54/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1895 - val_loss: -2.2328
# Epoch 55/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2172 - val_loss: -2.1470
# Epoch 56/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1935 - val_loss: -2.2659
# Epoch 57/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2082 - val_loss: -2.0471
# Epoch 58/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2081 - val_loss: -2.2641
# Epoch 59/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1941 - val_loss: -2.2225
# Epoch 60/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2105 - val_loss: -2.2027
# Epoch 61/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2271 - val_loss: -2.2216
# Epoch 62/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2445 - val_loss: -2.1448
# Epoch 63/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: -2.2097 - val_loss: -2.2891
# Epoch 64/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2291 - val_loss: -2.1778
# Epoch 65/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.1889 - val_loss: -2.1716
# Epoch 66/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: -2.2453 - val_loss: -2.2948
# Epoch 67/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2280 - val_loss: -2.2597
# Epoch 68/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2432 - val_loss: -2.2914
# Epoch 69/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2413 - val_loss: -2.1582
# Epoch 70/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2249 - val_loss: -2.2832
# Epoch 71/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2353 - val_loss: -2.2199
# Epoch 72/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2461 - val_loss: -2.3122
# Epoch 73/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2067 - val_loss: -2.1324
# Epoch 74/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2293 - val_loss: -2.2290
# Epoch 75/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2343 - val_loss: -2.2989
# Epoch 76/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2373 - val_loss: -2.1170
# Epoch 77/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: -2.2402 - val_loss: -2.1409
# Epoch 78/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2351 - val_loss: -2.3112
# Epoch 79/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2259 - val_loss: -2.1670
# Epoch 80/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2347 - val_loss: -2.1590
# Epoch 81/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2365 - val_loss: -2.2638
# Epoch 82/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2460 - val_loss: -2.1719
# Epoch 83/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2594 - val_loss: -2.2006
# Epoch 84/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2587 - val_loss: -2.1696
# Epoch 85/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2421 - val_loss: -2.2658
# Epoch 86/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2399 - val_loss: -2.3029
# Epoch 87/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2574 - val_loss: -2.2460
# Epoch 88/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2556 - val_loss: -2.1137
# Epoch 89/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2503 - val_loss: -2.3325
# Epoch 90/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2449 - val_loss: -2.2160
# Epoch 91/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2390 - val_loss: -2.1823
# Epoch 92/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2590 - val_loss: -2.1826
# Epoch 93/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2502 - val_loss: -2.2405
# Epoch 94/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2570 - val_loss: -2.3375
# Epoch 95/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2607 - val_loss: -2.2499
# Epoch 96/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2597 - val_loss: -2.2673
# Epoch 97/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2551 - val_loss: -2.2773
# Epoch 98/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2489 - val_loss: -2.2141
# Epoch 99/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2703 - val_loss: -2.2990
# Epoch 100/100
# 1095/1095 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: -2.2755 - val_loss: -2.0775

# %%
test_data = pd.read_csv('my_data.csv')
X_data = test_data[['x2', 'y2']].to_numpy()
Y_data = test_data[['q1', 'q2']].to_numpy()

X_temp, X_test, Y_temp, Y_test = train_test_split(
    X_data, Y_data, test_size=0.15, random_state=42
)
pred = model.predict(X_test)

def decode_mdn_output(pred):
    n_components = 2
    n_dims = 2

    pi_logits = pred[:, :n_components]
    pi = tf.nn.softmax(pi_logits).numpy()

    mu = pred[:, n_components:n_components + n_components * n_dims]
    mu = mu.reshape(-1, n_components, n_dims)

    sigma = pred[:, n_components + n_components * n_dims:]
    sigma = np.exp(sigma).reshape(-1, n_components, n_dims)

    return pi, mu, sigma

pi, mu, sigma = decode_mdn_output(pred)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
for i in range(6):
    print(f"Sample {i+1}:")
    print(f"  Input Cartesian (x2, y2): {X_test[i]}")
    print(f"  True joint angles (q1, q2): {Y_test[i]}")
    print(f"  Mixing probabilities: {pi[i]}")
    print(f"  Solution 1 mean (q1, q2): {mu[i, 0]} sigma: { sigma[i, 0]}")
    print(f"  Solution 2 mean (q1, q2): {mu[i, 1]} sigma: {sigma[i, 1]}")
    print()
# Out:
# Sample 1:
#   Input Cartesian (x2, y2): [0.10650741 1.99156165]
#   True joint angles (q1, q2): [1.44256806 0.14959965]
#   Mixing probabilities: [0.49760187 0.5023982 ]
#   Solution 1 mean (q1, q2): [ 1.5212431  -0.00725996] sigma: [0.04191417 0.08626003]
#   Solution 2 mean (q1, q2): [1.3847153  0.27436215] sigma: [0.0459852  0.09036323]
#
# Sample 2:
#   Input Cartesian (x2, y2): [ 1.49270611 -1.32680855]
#   True joint angles (q1, q2): [-0.67319843 -0.10685689]
#   Mixing probabilities: [0.5004656  0.49953443]
#   Solution 1 mean (q1, q2): [-0.5885706  -0.24642076] sigma: [0.07074798 0.1395567 ]
#   Solution 2 mean (q1, q2): [-0.8430928   0.24249679] sigma: [0.06483757 0.12854329]
#
# Sample 3:
#   Input Cartesian (x2, y2): [ 1.46200422 -1.35654167]
#   True joint angles (q1, q2): [-0.67319843 -0.14959965]
#   Mixing probabilities: [0.4984207 0.5015793]
#   Solution 1 mean (q1, q2): [-0.60408735 -0.25851706] sigma: [0.07212275 0.14198904]
#   Solution 2 mean (q1, q2): [-0.8706601   0.25443348] sigma: [0.06604922 0.13082263]
#
# Sample 4:
#   Input Cartesian (x2, y2): [0.5890289  1.71264558]
#   True joint angles (q1, q2): [0.8014267  0.87622652]
#   Mixing probabilities: [0.03474974 0.9652503 ]
#   Solution 1 mean (q1, q2): [ 1.5606503  -0.70234096] sigma: [0.01901237 0.0190175 ]
#   Solution 2 mean (q1, q2): [0.7912536  0.87559724] sigma: [0.02912291 0.05179036]
#
# Sample 5:
#   Input Cartesian (x2, y2): [1.20490791 1.57898257]
#   True joint angles (q1, q2): [0.8014267  0.23508516]
#   Mixing probabilities: [0.505579   0.49442098]
#   Solution 1 mean (q1, q2): [ 1.0386956  -0.24488178] sigma: [0.0659385  0.13084358]
#   Solution 2 mean (q1, q2): [0.80087394 0.23515837] sigma: [0.06086302 0.12103693]
#
# Sample 6:
#   Input Cartesian (x2, y2): [ 1.52951258 -1.19323248]
#   True joint angles (q1, q2): [-0.41674188 -0.49154171]
#   Mixing probabilities: [0.5001063  0.49989364]
#   Solution 1 mean (q1, q2): [-0.39025462 -0.52883446] sigma: [0.05385068 0.1035601 ]
#   Solution 2 mean (q1, q2): [-0.9171271   0.51291645] sigma: [0.04870451 0.09450057]

# %%
def count_out_of_bounds(q, q1_lim, q2_lim):
    q = np.atleast_2d(q)
    q1, q2 = q[:, 0], q[:, 1]
    valid_q1 = (q1_lim[0] <= q1) & (q1 <= q1_lim[1])
    valid_q2 = (q2_lim[0] <= q2) & (q2 <= q2_lim[1])
    valid_mask = valid_q1 & valid_q2

    total = len(valid_mask)
    invalid = np.sum(~valid_mask)
    print(f"Total samples: {total}")
    print(f"Out of bounds: {invalid} ({100 * invalid / total:.2f}%)")
    return None

count_out_of_bounds(mu[:,0,:], q1_lim=[-np.pi/2, np.pi/2], q2_lim=[-np.pi/3, np.pi/3])
count_out_of_bounds(mu[:,1,:], q1_lim=[-np.pi/2, np.pi/2], q2_lim=[-np.pi/3, np.pi/3])
# Out:
# Total samples: 375
# Out of bounds: 2 (0.53%)
# Total samples: 375
# Out of bounds: 17 (4.53%)

# %%
def evaluate_accuracy(robot, X_test, mu):
    _, ee_pred_0 = robot.forward_kinematics(mu[:, 0, :])
    _, ee_pred_1 = robot.forward_kinematics(mu[:, 1, :])

    errors_0 = np.linalg.norm(X_test - ee_pred_0, axis=1)
    errors_1 = np.linalg.norm(X_test - ee_pred_1, axis=1)

    avg_err0 = np.mean(errors_0)
    avg_err1 = np.mean(errors_1)

    return avg_err0, avg_err1

error_0, error_1 = evaluate_accuracy(robot, X_test, mu)
print(f"Average End-Effector Error (Mode 0): {error_0:.6f}")
print(f"Average End-Effector Error (Mode 1): {error_1:.6f}")
# Out:
# Average End-Effector Error (Mode 0): 0.027132
# Average End-Effector Error (Mode 1): 0.020960

# %%
# Plot solutions in Cartesian space
plt.figure(figsize=(6,6))
plt.scatter(X_test[:,0], X_test[:,1], color='blue', alpha=0.5, label='True')

# Plot both predicted modes for all test samples
_, x2y2_mode1= robot.forward_kinematics(mu[:,0,:])
_, x2y2_mode2 = robot.forward_kinematics(mu[:,1,:])
plt.scatter(x2y2_mode1[:,0], x2y2_mode1[:,1], color='red', alpha=0.5, label='Predicted mode 1')
plt.scatter(x2y2_mode2[:,0], x2y2_mode2[:,1], color='green', alpha=0.5, label='Predicted mode 2')

plt.legend()
plt.xlabel('x2')
plt.ylabel('y2')
plt.title('True vs. Predicted End-Effector Positions (Both Modes)')
plt.grid()
plt.show()

# %%
num_samples = 6
plt.figure(figsize=(12, 12))

for i in range(num_samples):
    plt.subplot(3, 2, i+1)

    # Ground-truth (blue)
    robot.plot(Y_test[i, 0], Y_test[i, 1], color='blue', label='True')

    # Predicted mode 1 (red)
    robot.plot(mu[i, 0, 0], mu[i, 0, 1], color='red', label='Predicted mode 1')

    # Predicted mode 2 (green)
    robot.plot(mu[i, 1, 0], mu[i, 1, 1], color='green', label='Predicted mode 2')

    plt.title(f'Sample {i+1}')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
